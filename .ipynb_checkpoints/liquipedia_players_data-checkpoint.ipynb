# %% [markdown]
# # Getting info on eSports players from Liquipedia

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import html5lib
import http

from time import sleep # in case liquipedia blocks me

# %%
players_df = pd.read_html('https://liquipedia.net/dota2/Players_(all)', header=0)[0]
players_df.drop(columns={'Unnamed: 0', 'Links'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-25-41ff7efba90f> in <module>()
# ----> 1 players_df = pd.read_html('https://liquipedia.net/dota2/Players_(all)', header=0)[0]
#       2 players_df.drop(columns={'Unnamed: 0', 'Links'}, inplace=True)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na)
#     913                   thousands=thousands, attrs=attrs, encoding=encoding,
#     914                   decimal=decimal, converters=converters, na_values=na_values,
# --> 915                   keep_default_na=keep_default_na)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, **kwargs)
#     747             break
#     748     else:
# --> 749         raise_with_traceback(retained)
#     750
#     751     ret = []
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#     383         if traceback == Ellipsis:
#     384             _, _, traceback = sys.exc_info()
# --> 385         raise exc.with_traceback(traceback)
#     386 else:
#     387     # this version of raise is a syntax error in Python 3
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
players_URL = 'https://liquipedia.net/dota2/Players_(all)'

players_links = []

res = requests.get(players_URL, headers=hdr)
tree = BeautifulSoup(res.text, 'html5lib')

for row in tree.find_all("tr"):
    link = tree.find_all("td")[1]
    players_links.append(link.a.get('href'))

# %%
tree.find_all("tr")[2].find_all("td")[1].a.get('href')
# Out:
# '/dota2/13abyKnight'

# %%
players_df.head()

# %%
players_ids = players_df['ID'].tolist()

# %%
players_meta_data = {}

hdr = { 'User-Agent' : 'sorry for that guys! my term paper is on fire!' }
h1 = http.client.HTTPConnection('www.liquipedia.net')

for player in players_ids:
    player_num = players_ids.index(player)
    players_meta_data[player_num] = {}
    
    res = requests.get('https://www.liquipedia.net/dota2/{player}'.format(player=player), headers=hdr)
    tree = BeautifulSoup(res.text, 'html5lib')
    
    players_meta_data[player_num].update({'player_id':player})
    
    # get meta data on teams
    descr_box = tree.find('div', class_='fo-nttax-infobox wiki-bordercolor-light')
    
    if descr_box is not None:
        
        # local name
        if descr_box.find(text='Name:') is not None:
            loc_name_raw = descr_box.find(text='Name:')
            loc_name = loc_name_raw.parent.parent.findNext('div').findNext('div').text
            players_meta_data[player_num].update({'local_name':loc_name})
        else:
            continue

        # name in latin
        if descr_box.find(text='Romanized Name:') is not None:
            name_raw = descr_box.find(text='Romanized Name:')
            name = name_raw.parent.parent.findNext('div').findNext('div').text
            players_meta_data[player_num].update({'name':name})
        else:
            continue

        # birth date
        if descr_box.find(text='Birth:') is not None:
            birth_raw = descr_box.find(text='Birth:')
            birth = birth_raw.parent.parent.findNext('div').findNext('div').text
            players_meta_data[player_num].update({'birth_date':birth})
        else:
            continue

        # current status
        if descr_box.find(text='Status:') is not None:
            status_raw = descr_box.find(text='Status:')
            status = status_raw.parent.parent.findNext('div').findNext('div').text
            players_meta_data[player_num].update({'status':status})
        else:
            continue

        # total earnings
        if descr_box.find(text='Approx. Total Earnings:') is not None:
            earn_raw = descr_box.find(text='Approx. Total Earnings:')
            earn = earn_raw.parent.parent.findNext('div').findNext('div').text
            earn = earn.replace('$','').replace(',','')
            players_meta_data[player_num].update({'total_earn':earn})
        else:
            continue
    else:
        continue
        
    sleep(2)
    
HTTPConnection.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-48c77e274ffa> in <module>()
#      63     sleep(2)
#      64
# ---> 65 HTTPConnection.close()
#
# NameError: name 'HTTPConnection' is not defined

# %%
players_meta_data
# Out:
# {0: {'player_id': '.Ark'},
#  1: {'player_id': '13abyKnight'},
#  2: {'player_id': '1437'},
#  3: {'player_id': '290'},
#  4: {'player_id': '2GD'},
#  5: {'player_id': '2hoi'},
#  6: {'player_id': '33'},
#  7: {'player_id': '4dr'},
#  8: {'player_id': '5400'},
#  9: {'player_id': '633'},
#  10: {'player_id': '71'},
#  11: {'player_id': '7ckngMad'},
#  12: {'player_id': '820'},
#  13: {'player_id': '86'},
#  14: {'player_id': '876'},
#  15: {'player_id': '897'},
#  16: {'player_id': '9pasha'},
#  17: {'player_id': '@dogf1ghts'},
#  18: {'player_id': 'aabBAA'},
#  19: {'player_id': 'Ab1ng'},
#  20: {'player_id': 'Abed'},
#  21: {'player_id': 'Accel'},
#  22: {'player_id': 'Ace'},
#  23: {'player_id': 'Adam'},
#  24: {'player_id': 'AdmiralBulldog'},
#  25: {'player_id': 'Admiration'},
#  26: {'player_id': 'Adong'},
#  27: {'player_id': 'ADTR'},
#  28: {'player_id': 'Afoninje'},
#  29: {'player_id': 'AfrOmoush'},
#  30: {'player_id': 'AfterLife'},
#  31: {'player_id': 'Agressif'},
#  32: {'player_id': 'ah fu'},
#  33: {'player_id': 'Ahjit'},
#  34: {'player_id': 'Air'},
#  35: {'player_id': 'Akke'},
#  36: {'player_id': 'Alex'},
#  37: {'player_id': 'ALOHADANCE'},
#  38: {'player_id': 'ALWAYSWANNAFLY'},
#  39: {'player_id': 'Ame'},
#  40: {'player_id': 'amoment'},
#  41: {'player_id': 'ana'},
#  42: {'player_id': 'AnneeDroid'},
#  43: {'player_id': 'Another'},
#  44: {'player_id': 'Apemother'},
#  45: {'player_id': 'Arise'},
#  46: {'player_id': 'Ariunbolor'},
#  47: {'player_id': 'Armel'},
#  48: {'player_id': 'Arms'},
#  49: {'player_id': 'ARS-ART'},
#  50: {'player_id': 'ArsZeeqq'},
#  51: {'player_id': 'Arteezy'},
#  52: {'player_id': 'Artes'},
#  53: {'player_id': 'Artstyle'},
#  54: {'player_id': 'Attacker'},
#  55: {'player_id': 'Atun'},
#  56: {'player_id': 'Atze'},
#  57: {'player_id': 'Aui_2000'},
#  58: {'player_id': 'AutumnWindz'},
#  59: {'player_id': 'Aville'},
#  60: {'player_id': 'Awoke'},
#  61: {'player_id': 'Ax.Mo'},
#  62: {'player_id': 'Axx'},
#  63: {'player_id': 'Axypa'},
#  64: {'player_id': 'Ayesee'},
#  65: {'player_id': 'Ayo'},
#  66: {'player_id': 'B'},
#  67: {'player_id': 'BafiK'},
#  68: {'player_id': 'Baga'},
#  69: {'player_id': 'Balsam'},
#  70: {'player_id': 'Banana'},
#  71: {'player_id': 'BananaSlamJamma'},
#  72: {'player_id': 'baNhwA'},
#  73: {'player_id': 'Barash'},
#  74: {'player_id': 'bardo'},
#  75: {'player_id': 'Barry'},
#  76: {'player_id': 'Bashruk'},
#  77: {'player_id': 'Basskip'},
#  78: {'player_id': 'BBC'},
#  79: {'player_id': 'Bdiz'},
#  80: {'player_id': 'Beesa'},
#  81: {'player_id': 'Ben'},
#  82: {'player_id': 'Benhur'},
#  83: {'player_id': 'Benjaz'},
#  84: {'player_id': 'Bignum'},
#  85: {'player_id': 'Bimbo'},
#  86: {'player_id': 'BinGo'},
#  87: {'player_id': 'Biryu'},
#  88: {'player_id': 'Biver'},
#  89: {'player_id': 'Black^'},
#  90: {'player_id': 'Blaze'},
#  91: {'player_id': 'Blazemon'},
#  92: {'player_id': 'bLink'},
#  93: {'player_id': 'Blitz'},
#  94: {'player_id': 'Blizzy'},
#  95: {'player_id': 'Bloody Nine'},
#  96: {'player_id': 'blowyourbrain'},
#  97: {'player_id': 'BoBoKa'},
#  98: {'player_id': 'Bok'},
#  99: {'player_id': 'bOne7'},
#  100: {'player_id': 'Boombacs'},
#  101: {'player_id': 'boombell'},
#  102: {'player_id': 'Boris'},
#  103: {'player_id': 'Boxi'},
#  104: {'player_id': 'Brax'},
#  105: {'player_id': 'BreakyCPK'},
#  106: {'player_id': 'Bruno'},
#  107: {'player_id': 'bryle'},
#  108: {'player_id': 'bubu'},
#  109: {'player_id': 'bukka'},
#  110: {'player_id': 'BuLba'},
#  111: {'player_id': 'BungsellRotee'},
#  112: {'player_id': 'BurNIng'},
#  113: {'player_id': 'Buugi'},
#  114: {'player_id': 'BYB'},
#  115: {'player_id': 'c4t'},
#  116: {'player_id': 'Cak3z'},
#  117: {'player_id': 'canceL^^'},
#  118: {'player_id': 'Capitalist'},
#  119: {'player_id': 'Carn'},
#  120: {'player_id': 'carrot'},
#  121: {'player_id': 'CartMaN'},
#  122: {'player_id': 'CaspeRRR'},
#  123: {'player_id': 'Cast'},
#  124: {'player_id': 'CC&C'},
#  125: {'player_id': 'CemaTheSlayer'},
#  126: {'player_id': 'Chains'},
#  127: {'player_id': 'Chalice'},
#  128: {'player_id': 'Chao'},
#  129: {'player_id': 'ChaoYue'},
#  130: {'player_id': 'Chappie'},
#  131: {'player_id': 'Chessie'},
#  132: {'player_id': 'Chibix'},
#  133: {'player_id': 'chisbug'},
#  134: {'player_id': 'Chrillee'},
#  135: {'player_id': 'chshrct'},
#  136: {'player_id': 'ChuaN'},
#  137: {'player_id': 'Chuvash'},
#  138: {'player_id': 'Clairvoyance'},
#  139: {'player_id': 'ComeWithMe'},
#  140: {'player_id': 'Conrad'},
#  141: {'player_id': 'Cookie bear'},
#  142: {'player_id': 'Cooman'},
#  143: {'player_id': 'Corey'},
#  144: {'player_id': 'Costabile'},
#  145: {'player_id': 'Cr1t-'},
#  146: {'player_id': 'craNich'},
#  147: {'player_id': 'Crazy'},
#  148: {'player_id': 'Crio_J'},
#  149: {'player_id': 'Crydasia'},
#  150: {'player_id': 'Crystallize'},
#  151: {'player_id': 'Cty'},
#  152: {'player_id': 'Cy'},
#  153: {'player_id': 'Cyborgmatt'},
#  154: {'player_id': 'CyNiCaL'},
#  155: {'player_id': 'Cys'},
#  156: {'player_id': 'cYso'},
#  157: {'player_id': 'dabeliuteef'},
#  158: {'player_id': 'DancingDragon'},
#  159: {'player_id': 'dark'},
#  160: {'player_id': 'DD'},
#  161: {'player_id': 'ddc'},
#  162: {'player_id': 'DDR'},
#  163: {'player_id': 'DDX-'},
#  164: {'player_id': 'ddz'},
#  165: {'player_id': 'DeMoN'},
#  166: {'player_id': 'Dendi'},
#  167: {'player_id': 'destiny'},
#  168: {'player_id': 'Ditya Ra'},
#  169: {'player_id': 'DJ'},
#  170: {'player_id': 'DkPhobos'},
#  171: {'player_id': 'dnz'},
#  172: {'player_id': 'Doctor'},
#  173: {'player_id': 'Dog_7'},
#  174: {'player_id': 'doodle'},
#  175: {'player_id': 'Draskyl'},
#  176: {'player_id': 'Drayich'},
#  177: {'player_id': 'Dread'},
#  178: {'player_id': 'Dreamocel'},
#  179: {'player_id': 'DreamyU'},
#  180: {'player_id': 'Droog'},
#  181: {'player_id': 'DuBu'},
#  182: {'player_id': 'DurpDurp'},
#  183: {'player_id': 'Duster'},
#  184: {'player_id': 'Dutch_Freak'},
#  185: {'player_id': 'DXM'},
#  186: {'player_id': 'Dy'},
#  187: {'player_id': 'Eagle'},
#  188: {'player_id': 'Ecnart'},
#  189: {'player_id': 'EGM'},
#  190: {'player_id': 'eL lisasH'},
#  191: {'player_id': 'eLeVeN'},
#  192: {'player_id': 'END'},
#  193: {'player_id': 'Eosin'},
#  194: {'player_id': 'Era'},
#  195: {'player_id': 'eresloco'},
#  196: {'player_id': 'Eri Neeman'},
#  197: {'player_id': 'Eskillz'},
#  198: {'player_id': 'Etakaka'},
#  199: {'player_id': 'EternaLEnVy'},
#  200: {'player_id': 'Ewe'},
#  201: {'player_id': 'Excalibur'},
#  202: {'player_id': 'Exotic_Deer'},
#  203: {'player_id': 'eyyou'},
#  204: {'player_id': 'f(x)'},
#  205: {'player_id': 'Fade'},
#  206: {'player_id': 'Faith'},
#  207: {'player_id': 'Faith_bian'},
#  208: {'player_id': 'FaN'},
#  209: {'player_id': 'Fata'},
#  210: {'player_id': 'Fear'},
#  211: {'player_id': 'Feaver'},
#  212: {'player_id': 'Febby'},
#  213: {'player_id': 'Feero'},
#  214: {'player_id': 'Fenrir'},
#  215: {'player_id': 'Ferrari_430'},
#  216: {'player_id': 'Fervian'},
#  217: {'player_id': 'Fey'},
#  218: {'player_id': 'Fishbone'},
#  219: {'player_id': 'Five'},
#  220: {'player_id': 'Flens'},
#  221: {'player_id': 'Flow'},
#  222: {'player_id': 'FLUFFNSTUFF'},
#  223: {'player_id': 'Fly'},
#  224: {'player_id': 'Fly.'},
#  225: {'player_id': 'Flyby'},
#  226: {'player_id': 'FlyingZebra'},
#  227: {'player_id': 'Flysolo'},
#  228: {'player_id': 'fn'},
#  229: {'player_id': 'fng'},
#  230: {'player_id': 'Fogged'},
#  231: {'player_id': 'Fonte'},
#  232: {'player_id': 'Forev'},
#  233: {'player_id': 'Foxx'},
#  234: {'player_id': 'FrancisLee'},
#  235: {'player_id': 'Freeze'},
#  236: {'player_id': 'Frigoleet'},
#  237: {'player_id': 'Fronz'},
#  238: {'player_id': 'Frost'},
#  239: {'player_id': 'fROZEN'},
#  240: {'player_id': 'Funn1k'},
#  241: {'player_id': 'Funzii'},
#  242: {'player_id': 'Fusheng'},
#  243: {'player_id': 'fy'},
#  244: {'player_id': 'Fyms'},
#  245: {'player_id': 'FzFz'},
#  246: {'player_id': 'G'},
#  247: {'player_id': 'g0g1'},
#  248: {'player_id': 'Gabbi'},
#  249: {'player_id': 'Gambling'},
#  250: {'player_id': 'Garder'},
#  251: {'player_id': 'Gareth'},
#  252: {'player_id': 'garter'},
#  253: {'player_id': 'Gedrox'},
#  254: {'player_id': 'GeneRaL'},
#  255: {'player_id': 'german player'},
#  256: {'player_id': 'GGwpLanaya'},
#  257: {'player_id': 'GH'},
#  258: {'player_id': 'ghost'},
#  259: {'player_id': 'Ghostik'},
#  260: {'player_id': 'GiGA'},
#  261: {'player_id': 'Gintoki'},
#  262: {'player_id': 'Gio'},
#  263: {'player_id': 'gnoji'},
#  264: {'player_id': 'GoAudio'},
#  265: {'player_id': 'Goblak'},
#  266: {'player_id': 'goddam'},
#  267: {'player_id': 'Godot'},
#  268: {'player_id': 'GoDz'},
#  269: {'player_id': 'goking'},
#  270: {'player_id': 'Gorec'},
#  271: {'player_id': 'Gorgc'},
#  272: {'player_id': 'GranDGranT'},
#  273: {'player_id': 'Greedy'},
#  274: {'player_id': 'guanzo'},
#  275: {'player_id': 'Gudii'},
#  276: {'player_id': 'Guvara'},
#  277: {'player_id': 'H4nn1'},
#  278: {'player_id': 'Handsken'},
#  279: {'player_id': 'HANNAH_MONTANA'},
#  280: {'player_id': 'Hao'},
#  281: {'player_id': 'Heen'},
#  282: {'player_id': 'Heromu'},
#  283: {'player_id': 'HesteJoe-Rotten'},
#  284: {'player_id': 'hex0r'},
#  285: {'player_id': 'hFn'},
#  286: {'player_id': 'Hook-'},
#  287: {'player_id': 'HooNji'},
#  288: {'player_id': 'Hot_Bid'},
#  289: {'player_id': 'Hugo'},
#  290: {'player_id': 'Hy'},
#  291: {'player_id': 'Hyac'},
#  292: {'player_id': 'hyhy'},
#  293: {'player_id': 'Hym'},
#  294: {'player_id': 'i w o'},
#  295: {'player_id': 'iAnnihilate'},
#  296: {'player_id': 'Ice'},
#  297: {'player_id': 'Iceberg'},
#  298: {'player_id': 'iceice'},
#  299: {'player_id': 'iceiceice'},
#  300: {'player_id': 'Icy'},
#  301: {'player_id': 'Ifrit'},
#  302: {'player_id': 'Illidan'},
#  303: {'player_id': 'ilLogic'},
#  304: {'player_id': 'iLLusionisT'},
#  305: {'player_id': 'iLTW'},
#  306: {'player_id': 'ima_sheep(sux)'},
#  307: {'player_id': 'Inflame'},
#  308: {'player_id': 'InJuly'},
#  309: {'player_id': 'Inkvizitor'},
#  310: {'player_id': 'Inmate'},
#  311: {'player_id': 'iNSaNiA'},
#  312: {'player_id': 'Inverno'},
#  313: {'player_id': 'inYourdreaM'},
#  314: {'player_id': 'ixmike88'},
#  315: {'player_id': 'j4'},
#  316: {'player_id': 'Jabbz'},
#  317: {'player_id': 'Jabz'},
#  318: {'player_id': 'Jackal'},
#  319: {'player_id': 'Jacko'},
#  320: {'player_id': 'jaH'},
#  321: {'player_id': 'James'},
#  322: {'player_id': 'Jason'},
#  323: {'player_id': 'jdh'},
#  324: {'player_id': 'Jenkins'},
#  325: {'player_id': 'Jeppins'},
#  326: {'player_id': 'JerAx'},
#  327: {'player_id': 'Jericho'},
#  328: {'player_id': 'Jerry'},
#  329: {'player_id': 'JessieVash'},
#  330: {'player_id': 'JesusSt1ck'},
#  331: {'player_id': 'Jeyo'},
#  332: {'player_id': 'Jhoven'},
#  333: {'player_id': 'JiaJia'},
#  334: {'player_id': 'jigglebilly'},
#  335: {'player_id': 'Jixing'},
#  336: {'player_id': 'JoHnNy'},
#  337: {'player_id': 'jonassomfan'},
#  338: {'player_id': 'Joraal'},
#  339: {'player_id': 'JotM'},
#  340: {'player_id': 'Jubei'},
#  341: {'player_id': 'Julz'},
#  342: {'player_id': 'June'},
#  343: {'player_id': 'JUST'},
#  344: {'player_id': 'justin'},
#  345: {'player_id': 'JyC'},
#  346: {'player_id': 'JyU'},
#  347: {'player_id': 'Kabu'},
#  348: {'player_id': 'Kaci Aitchison'},
#  349: {'player_id': 'kacor'},
#  350: {'player_id': 'KaHT'},
#  351: {'player_id': 'Kai'},
#  352: {'player_id': 'kaidou'},
#  353: {'player_id': 'Kaka'},
#  354: {'player_id': 'KaNG'},
#  355: {'player_id': 'KBBQ'},
#  356: {'player_id': 'Kebap'},
#  357: {'player_id': 'Kecik Imba'},
#  358: {'player_id': 'Kefka'},
#  359: {'player_id': 'KeyaNo'},
#  360: {'player_id': 'Keyser'},
#  361: {'player_id': 'KheZu'},
#  362: {'player_id': 'Kikoni'},
#  363: {'player_id': 'Kim0'},
#  364: {'player_id': 'KingJ'},
#  365: {'player_id': 'KingR'},
#  366: {'player_id': 'Kingrd'},
#  367: {'player_id': 'Kingteka'},
#  368: {'player_id': 'Kipspul'},
#  369: {'player_id': 'Klasynky'},
#  370: {'player_id': 'Klotz22'},
#  371: {'player_id': 'Koala'},
#  372: {'player_id': 'kole'},
#  373: {'player_id': 'Korok'},
#  374: {'player_id': 'Kotarō Hayama'},
#  375: {'player_id': 'KotLGuy'},
#  376: {'player_id': 'kpii'},
#  377: {'player_id': 'Kpoptosis'},
#  378: {'player_id': 'KSi'},
#  379: {'player_id': 'Kuku'},
#  380: {'player_id': 'Kumi'},
#  381: {'player_id': 'KuroKy'},
#  382: {'player_id': 'KvH'},
#  383: {'player_id': 'Kyle'},
#  384: {'player_id': 'KyrieDepra'},
#  385: {'player_id': 'KyT'},
#  386: {'player_id': 'kYxY'},
#  387: {'player_id': 'L0lik_O'},
#  388: {'player_id': 'Lacoste'},
#  389: {'player_id': 'LaKelz'},
#  390: {'player_id': 'Lanaro'},
#  391: {'player_id': 'Lance'},
#  392: {'player_id': 'LaNm'},
#  393: {'player_id': 'Lapiz'},
#  394: {'player_id': 'LD'},
#  395: {'player_id': 'le'},
#  396: {'player_id': 'LeBronDota'},
#  397: {'player_id': 'LeoStyle-'},
#  398: {'player_id': 'Ler_GG'},
#  399: {'player_id': 'Li'},
#  400: {'player_id': 'Liekkas'},
#  401: {'player_id': 'LighTofHeaveN'},
#  402: {'player_id': 'Lil'},
#  403: {'player_id': 'Lil_kin6'},
#  404: {'player_id': 'Limmp'},
#  405: {'player_id': 'Lin'},
#  406: {'player_id': 'ling'},
#  407: {'player_id': 'Link'},
#  408: {'player_id': 'Liposa'},
#  409: {'player_id': 'lizZard'},
#  410: {'player_id': 'Loda'},
#  411: {'player_id': 'longb'},
#  412: {'player_id': 'LongDD'},
#  413: {'player_id': 'Loomdun'},
#  414: {'player_id': 'lordboonz'},
#  415: {'player_id': 'Lpc'},
#  416: {'player_id': 'lt'},
#  417: {'player_id': 'Lubby'},
#  418: {'player_id': 'Luft'},
#  419: {'player_id': 'LuLu^^'},
#  420: {'player_id': 'Luminous'},
#  421: {'player_id': 'Lwy'},
#  422: {'player_id': 'Lyrical'},
#  423: {'player_id': 'Machine'},
#  424: {'player_id': 'Madara'},
#  425: {'player_id': 'Maden'},
#  426: {'player_id': 'Maelk'},
#  427: {'player_id': 'MafiA'},
#  428: {'player_id': 'Mag'},
#  429: {'player_id': 'MagE-'},
#  430: {'player_id': 'MaGoma'},
#  431: {'player_id': 'maiki'},
#  432: {'player_id': 'Mambos'},
#  433: {'player_id': 'Mandy'},
#  434: {'player_id': 'Mango_Banana'},
#  435: {'player_id': 'MaNia'},
#  436: {'player_id': 'Mantis'},
#  437: {'player_id': 'maomao'},
#  438: {'player_id': 'March'},
#  439: {'player_id': 'marSu'},
#  440: {'player_id': 'Masakary'},
#  441: {'player_id': 'Masoku'},
#  442: {'player_id': 'mason'},
#  443: {'player_id': 'Masquerade'},
#  444: {'player_id': 'Massacre'},
#  445: {'player_id': 'Mastermind'},
#  446: {'player_id': 'Matrim'},
#  447: {'player_id': 'Matthew'},
#  448: {'player_id': 'MATUMBAMAN'},
#  449: {'player_id': 'Maut'},
#  450: {'player_id': 'Maybe Next Time'},
#  451: {'player_id': 'mdL'},
#  452: {'player_id': 'MelodyLovers'},
#  453: {'player_id': 'Meracle'},
#  454: {'player_id': 'Merlini'},
#  455: {'player_id': 'MeTTpuM'},
#  456: {'player_id': 'Mevius'},
#  457: {'player_id': 'miCKe'},
#  458: {'player_id': 'MidOne'},
#  459: {'player_id': 'miGGel'},
#  460: {'player_id': 'MiHawk'},
#  461: {'player_id': 'Mikasa'},
#  462: {'player_id': 'Mikey'},
#  463: {'player_id': 'MiLAN'},
#  464: {'player_id': 'MinD_ContRoL'},
#  465: {'player_id': 'Minerva'},
#  466: {'player_id': 'Mini'},
#  467: {'player_id': 'Miposhka'},
#  468: {'player_id': 'Miracle-'},
#  469: {'player_id': 'Mirakel'},
#  470: {'player_id': 'MISERY'},
#  471: {'player_id': 'Misha'},
#  472: {'player_id': 'Mitch'},
#  473: {'player_id': 'MJW'},
#  474: {'player_id': 'MMY!'},
#  475: {'player_id': 'Mofi'},
#  476: {'player_id': 'Monet'},
#  477: {'player_id': 'monkeys-forever'},
#  478: {'player_id': 'Monolith'},
#  479: {'player_id': 'Moo'},
#  480: {'player_id': 'Moogy'},
#  481: {'player_id': 'mool'},
#  482: {'player_id': 'Moon'},
#  483: {'player_id': 'Moonlight'},
#  484: {'player_id': 'MoonMeander'},
#  485: {'player_id': 'MoZuN-'},
#  486: {'player_id': 'MP'},
#  487: {'player_id': 'Mrrr'},
#  488: {'player_id': 'MS'},
#  489: {'player_id': 'MSS'},
#  490: {'player_id': 'mstco'},
#  491: {'player_id': 'MtR'},
#  492: {'player_id': 'Mtrx4u'},
#  493: {'player_id': 'Mu'},
#  494: {'player_id': 'Mushi'},
#  495: {'player_id': 'Mynuts'},
#  496: {'player_id': 'MyPro'},
#  497: {'player_id': 'N0tail'},
#  498: {'player_id': 'Nafari'},
#  499: {'player_id': 'Nahaz'},
#  500: {'player_id': 'Naive-'},
#  501: {'player_id': 'Nando'},
#  502: {'player_id': 'NeaR'},
#  503: {'player_id': 'Nedbone'},
#  504: {'player_id': 'nemphy'},
#  505: {'player_id': 'NEQROMAN'},
#  506: {'player_id': 'Net'},
#  507: {'player_id': 'Newsham'},
#  508: {'player_id': 'Nexus'},
#  509: {'player_id': 'Nikobaby'},
#  510: {'player_id': 'Nine'},
#  511: {'player_id': 'ninjaboogie'},
#  512: {'player_id': 'Niqua'},
#  513: {'player_id': 'Nisha'},
#  514: {'player_id': 'Nix'},
#  515: {'player_id': 'Nj'},
#  516: {'player_id': 'NO_Chanc3'},
#  517: {'player_id': 'noble'},
#  518: {'player_id': 'Nofear'},
#  519: {'player_id': 'Noia'},
#  520: {'player_id': 'Nokky'},
#  521: {'player_id': 'nongrata'},
#  522: {'player_id': 'Nono'},
#  523: {'player_id': 'Noone'},
#  524: {'player_id': 'Noxville'},
#  525: {'player_id': 'NS'},
#  526: {'player_id': 'NutZ'},
#  527: {'player_id': 'ODPixel'},
#  528: {'player_id': 'Offak'},
#  529: {'player_id': 'Ohaiyo'},
#  530: {'player_id': 'old chicken'},
#  531: {'player_id': 'oliver'},
#  532: {'player_id': 'OmegaPwner'},
#  533: {'player_id': 'Op'},
#  534: {'player_id': 'Ori'},
#  535: {'player_id': 'Origami'},
#  536: {'player_id': 'Owa'},
#  537: {'player_id': 'PAADA'},
#  538: {'player_id': 'Pablo'},
#  539: {'player_id': 'Pajkatt'},
#  540: {'player_id': 'Palantimos'},
#  541: {'player_id': 'Pandaego'},
#  542: {'player_id': 'Paparazi灬'},
#  543: {'player_id': 'Papita'},
#  544: {'player_id': 'PARIS'},
#  545: {'player_id': 'paS'},
#  546: {'player_id': 'Patos'},
#  547: {'player_id': 'PatSoul'},
#  548: {'player_id': 'PGG'},
#  549: {'player_id': 'Piao'},
#  550: {'player_id': 'pieliedie'},
#  551: {'player_id': 'Pikachu'},
#  552: {'player_id': 'PimpmuckL'},
#  553: {'player_id': 'Pingvincek'},
#  554: {'player_id': 'PiNoY'},
#  555: {'player_id': 'PlayHard'},
#  556: {'player_id': 'PLZDunKilme'},
#  557: {'player_id': 'Poloson'},
#  558: {'player_id': 'ppd'},
#  559: {'player_id': 'PrettyHaw'},
#  560: {'player_id': 'Primo'},
#  561: {'player_id': 'profheadshot'},
#  562: {'player_id': 'PSM'},
#  563: {'player_id': 'Puer tea'},
#  564: {'player_id': 'Puppey'},
#  565: {'player_id': 'Purge'},
#  566: {'player_id': 'pwN'},
#  567: {'player_id': 'PyrionFlax'},
#  568: {'player_id': 'pYung'},
#  569: {'player_id': 'Q'},
#  570: {'player_id': 'qd'},
#  571: {'player_id': 'qianqian'},
#  572: {'player_id': 'QO'},
#  573: {'player_id': 'qojqva'},
#  574: {'player_id': 'QQQ'},
#  575: {'player_id': 'QwisTa'},
#  576: {'player_id': 'r1sk'},
#  577: {'player_id': 'r5r5'},
#  578: {'player_id': 'Rabbit'},
#  579: {'player_id': 'RAI'},
#  580: {'player_id': 'RAMZES666'},
#  581: {'player_id': 'Ran'},
#  582: {'player_id': 'Rapy'},
#  583: {'player_id': 'Raven'},
#  584: {'player_id': 'ReaLaxXx'},
#  585: {'player_id': 'Reaves'},
#  586: {'player_id': 'Red'},
#  587: {'player_id': 'Redeye'},
#  588: {'player_id': 'Reelo'},
#  589: {'player_id': 'Reesion'},
#  590: {'player_id': 'Reisen'},
#  591: {'player_id': 'Resolut1on'},
#  592: {'player_id': 'Retribution'},
#  593: {'player_id': 'Rime'},
#  594: {'player_id': 'Riser'},
#  595: {'player_id': 'Ritsu'},
#  596: {'player_id': 'RMC'},
#  597: {'player_id': 'rmN-'},
#  598: {'player_id': 'Roddgeee'},
#  599: {'player_id': 'RodjER'},
#  600: {'player_id': 'RogerDodger'},
#  601: {'player_id': 'Rong'},
#  602: {'player_id': 'rOtK'},
#  603: {'player_id': 'RR'},
#  604: {'player_id': 'Runec'},
#  605: {'player_id': 'Ryoya'},
#  606: {'player_id': 'ryOyr'},
#  607: {'player_id': 'RyuUboruZ'},
#  608: {'player_id': 'Ryuya'},
#  609: {'player_id': 'Ryze'},
#  610: {'player_id': 's4'},
#  611: {'player_id': 'Sag'},
#  612: {'player_id': 'Sai'},
#  613: {'player_id': 'Sakata'},
#  614: {'player_id': 'Saksa'},
#  615: {'player_id': 'Sam_H'},
#  616: {'player_id': 'SangSang'},
#  617: {'player_id': 'SANKE'},
#  618: {'player_id': 'SanSheng'},
#  619: {'player_id': 'Santa'},
#  620: {'player_id': 'Sayaka'},
#  621: {'player_id': 'Scabo'},
#  622: {'player_id': 'Scandal'},
#  623: {'player_id': 'scant'},
#  624: {'player_id': 'Sccc'},
#  625: {'player_id': 'SCL'},
#  626: {'player_id': 'Scofield'},
#  627: {'player_id': 'SCripted'},
#  628: {'player_id': 'sD'},
#  629: {'player_id': 'Sealkid'},
#  630: {'player_id': 'Sedoy'},
#  631: {'player_id': 'SeleCT'},
#  632: {'player_id': 'Seleri'},
#  633: {'player_id': 'September'},
#  634: {'player_id': 'Setsu'},
#  635: {'player_id': 'Seven'},
#  636: {'player_id': 'SexyBamboe'},
#  637: {'player_id': 'Sh4dowehhh'},
#  638: {'player_id': 'Shachlo'},
#  639: {'player_id': 'shadow'},
#  640: {'player_id': 'shaker'},
#  641: {'player_id': 'Shaneomad'},
#  642: {'player_id': 'Sharky'},
#  643: {'player_id': 'shatan'},
#  644: {'player_id': 'Sheever'},
#  645: {'player_id': 'Shiibbyy'},
#  646: {'player_id': 'Shiki'},
#  647: {'player_id': 'Shining'},
#  648: {'player_id': 'Shredder'},
#  649: {'player_id': 'Sifla'},
#  650: {'player_id': 'Silent'},
#  651: {'player_id': 'SingSing'},
#  652: {'player_id': 'SirActionSlacks'},
#  653: {'player_id': 'SKANKS224'},
#  654: {'player_id': 'Skemberlu'},
#  655: {'player_id': 'skrff'},
#  656: {'player_id': 'Sky'},
#  657: {'player_id': 'SkyLark'},
#  658: {'player_id': 'slahser'},
#  659: {'player_id': 'Slander'},
#  660: {'player_id': 'SlashStrike'},
#  661: {'player_id': 'Slayer'},
#  662: {'player_id': 'SLiCKz'},
#  663: {'player_id': 'SmAsH'},
#  664: {'player_id': 'smulgullig'},
#  665: {'player_id': 'Sneyking'},
#  666: {'player_id': 'Snoopy'},
#  667: {'player_id': 'Sober'},
#  668: {'player_id': 'Solen'},
#  669: {'player_id': 'Solitude'},
#  670: {'player_id': 'Solo'},
#  671: {'player_id': 'Somnus丶M'},
#  672: {'player_id': 'SoNNeikO'},
#  673: {'player_id': 'Sooths'},
#  674: {'player_id': 'Sovereign'},
#  675: {'player_id': 'Spin'},
#  676: {'player_id': 'sQreen'},
#  677: {'player_id': 'Srf'},
#  678: {'player_id': 'SsaSpartan'},
#  679: {'player_id': 'sss'},
#  680: {'player_id': 'STABA'},
#  681: {'player_id': 'Stan King'},
#  682: {'player_id': 'State21'},
#  683: {'player_id': 'Steffstyle'},
#  684: {'player_id': 'StingeR'},
#  685: {'player_id': 'Stomanen1'},
#  686: {'player_id': 'Strangby'},
#  687: {'player_id': 'sugar baby'},
#  688: {'player_id': 'SumaiL'},
#  689: {'player_id': 'SunBhie'},
#  690: {'player_id': 'Sune'},
#  691: {'player_id': 'Sunlight'},
#  692: {'player_id': 'SUNSfan'},
#  693: {'player_id': 'Super'},
#  694: {'player_id': 'super'},
#  695: {'player_id': 'Supreme'},
#  696: {'player_id': 'SVG'},
#  697: {'player_id': 'Swiftending'},
#  698: {'player_id': 'Swifty'},
#  699: {'player_id': 'Syeonix'},
#  700: {'player_id': 'Sylar'},
#  701: {'player_id': 'syndereN'},
#  702: {'player_id': 'Taiga'},
#  703: {'player_id': 'Tavo'},
#  704: {'player_id': 'TC'},
#  705: {'player_id': 'Teehee'},
#  706: {'player_id': 'The_apathy'},
#  707: {'player_id': 'TheHeartlessKing'},
#  708: {'player_id': 'Therence'},
#  709: {'player_id': 'Thiolicor'},
#  710: {'player_id': 'ThuG'},
#  711: {'player_id': 'TidesofTime'},
#  712: {'player_id': 'Timado'},
#  713: {'player_id': 'Tims'},
#  714: {'player_id': 'TnK'},
#  715: {'player_id': 'TobiWan'},
#  716: {'player_id': 'Toffees'},
#  717: {'player_id': 'Tone'},
#  718: {'player_id': 'TooFuckingGood'},
#  719: {'player_id': 'Topson'},
#  720: {'player_id': 'TpoH'},
#  721: {'player_id': 'Tralf'},
#  722: {'player_id': 'TrentPax'},
#  723: {'player_id': 'Trixi'},
#  724: {'player_id': 'Tsunami'},
#  725: {'player_id': 'Tudi'},
#  726: {'player_id': 'Tulex'},
#  727: {'player_id': 'TuTu'},
#  728: {'player_id': 'twiSta'},
#  729: {'player_id': 'ubah'},
#  730: {'player_id': 'UnderShock'},
#  731: {'player_id': 'unicornxoxo'},
#  732: {'player_id': 'UNiVeRsE'},
#  733: {'player_id': 'USH'},
#  734: {'player_id': 'v0ja'},
#  735: {'player_id': 'v1lat'},
#  736: {'player_id': 'Vaalix'},
#  737: {'player_id': 'vandersar'},
#  738: {'player_id': 'vanN'},
#  739: {'player_id': 'VANSKOR'},
#  740: {'player_id': 'velheor'},
#  741: {'player_id': 'Velo'},
#  742: {'player_id': 'Victoria'},
#  743: {'player_id': 'Vigoss'},
#  744: {'player_id': 'w33'},
#  745: {'player_id': 'Wagamama'},
#  746: {'player_id': 'Waixi'},
#  747: {'player_id': 'Warlog'},
#  748: {'player_id': 'Waytosexy'},
#  749: {'player_id': 'weddingcrash'},
#  750: {'player_id': 'wejustzik'},
#  751: {'player_id': 'Wenn'},
#  752: {'player_id': 'Weppas'},
#  753: {'player_id': 'whiteBeard'},
#  754: {'player_id': 'Windx'},
#  755: {'player_id': 'WinteR'},
#  756: {'player_id': 'WwD'},
#  757: {'player_id': 'wwieWambo'},
#  758: {'player_id': 'XaKoH'},
#  759: {'player_id': 'XBOCT'},
#  760: {'player_id': 'XDD'},
#  761: {'player_id': 'Xepher'},
#  762: {'player_id': 'xFreedom'},
#  763: {'player_id': 'Xi'},
#  764: {'player_id': 'xiangzai'},
#  765: {'player_id': 'Xiao2lei'},
#  766: {'player_id': 'xiao8'},
#  767: {'player_id': 'xiaofu'},
#  768: {'player_id': 'XiaoXiao'},
#  769: {'player_id': 'XinQ'},
#  770: {'player_id': 'xLucky'},
#  771: {'player_id': 'xMusiCa'},
#  772: {'player_id': 'xNova'},
#  773: {'player_id': 'xRag'},
#  774: {'player_id': 'XtiNcT'},
#  775: {'player_id': 'Xtt'},
#  776: {'player_id': 'xuan'},
#  777: {'player_id': 'Xxs'},
#  778: {'player_id': 'XXSJ'},
#  779: {'player_id': 'xy-'},
#  780: {'player_id': 'Xyclopz'},
#  781: {'player_id': 'Xz'},
#  782: {'player_id': 'y`'},
#  783: {'player_id': 'Yabyoo'},
#  784: {'player_id': 'yAj'},
#  785: {'player_id': 'YamateH'},
#  786: {'player_id': 'Yang'},
#  787: {'player_id': 'Yao'},
#  788: {'player_id': 'YaphetS'},
#  789: {'player_id': 'YapzOr'},
#  790: {'player_id': 'YawaR'},
#  791: {'player_id': 'yChen'},
#  792: {'player_id': 'Yin'},
#  793: {'player_id': 'yoky-'},
#  794: {'player_id': 'yol'},
#  795: {'player_id': 'yoona'},
#  796: {'player_id': 'YRG'},
#  797: {'player_id': 'Ysaera'},
#  798: {'player_id': 'yxb'},
#  799: {'player_id': 'yxl'},
#  800: {'player_id': 'YYF'},
#  801: {'player_id': 'Zacky'},
#  802: {'player_id': 'zai'},
#  803: {'player_id': 'Zayac'},
#  804: {'player_id': 'Zenigata'},
#  805: {'player_id': 'Zeroji'},
#  806: {'player_id': 'ZeroPerfect'},
#  807: {'player_id': 'Zfreek'},
#  808: {'player_id': 'zhizhizhi'},
#  809: {'player_id': 'Zhou'},
#  810: {'player_id': 'ZippO'},
#  811: {'player_id': 'Zizou'},
#  812: {'player_id': 'ZSMJ'},
#  813: {'player_id': 'Ztok'},
#  814: {'player_id': 'zxc'},
#  815: {'player_id': 'Zyori'},
#  816: {'player_id': 'Zyzz'},
#  817: {'player_id': 'Женя'},
#  818: {'player_id': '冷鸟'},
#  819: {'player_id': '垃圾君'},
#  820: {'player_id': '天命'},
#  821: {'player_id': '小郭嘉'},
#  822: {'player_id': '老A'},
#  823: {'player_id': '荧'},
#  824: {'player_id': '闷油瓶'}}

# %%
tree
# Out:
# <!DOCTYPE html>
# <html><head><title>Rate Limited</title><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1" name="viewport"/><style type="text/css">body{margin:40px auto;max-width:650px;line-height:1.6;font-size:18px;color:#444;padding:0 10px}h1{line-height:1.2}.reason{display:none}</style><script src="https://www.google.com/recaptcha/api.js"></script></head><body><h1>Rate Limited</h1><p>Your IP address has been temporarily blocked from accessing Liquipedia due to invalid or excessive requests. This may happen if you're using a scraper / bot or otherwise accessing pages too quickly. Scrapers and similar tools are not permitted to access Liquipedia. Please see <a href="http://www.teamliquid.net/forum/hidden/491339-liquipedia-api-usage-guidelines">the Liquipedia API usage guidelines</a> for information on how to access to Liquipedia data in a supported manner. Rate limiting may also be triggered by problematic browser extensions, excessive pre-fetching or corporate content scanners.</p><div class="reason" id="cheetah"><h2>Cheetah Browser Detected</h2><p>You seem to be using "Cheetah Browser" / "CM Browser" / "çè±¹å®å
# ¨æµè§å¨". This browser opens many connections to Liquipedia as part of the preloading feature. Please disable the preloading feature in order to avoid becoming blocked due to this browser.</p></div><p>To restore access to Liquipedia, please complete the CAPTCHA to unblock your IP:</p><form action="/unblock" method="post"><input id="r" name="r" type="hidden"/><div class="g-recaptcha" data-sitekey="6LfmmiMUAAAAAM6iunApG9ilrc4jTIUcOfv9xYNX"></div><input type="submit" value="Unblock"/></form><p></p><p>Note that unblocking your IP will not whitelist it; you may still be rate limited again if you do not fix whatever caused you to be blocked.</p><script>document.getElementById('r').value = window.location.href;if (navigator.userAgent.indexOf ("LBBROWSER") != -1)document.getElementById('cheetah').style.display = "block";</script><!-- Triggered by REMOTE_ADDR for REQUEST_URI at TIME_ISO8601 --></body></html>
